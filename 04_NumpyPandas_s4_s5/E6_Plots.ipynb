# %% [markdown]
# # Plots

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ___

# %% [markdown]
# ## Plots

# %% [markdown]
# - Crea dos array (x e y):
#     - x: 1000 números equiespaciados entre 0 a 3$\pi$
#     - y: Resultado de aplicar la función $f(x) = \frac{1}{2}\sin^2(10 x) + \cos(x)$

# %%
#COGER EJERCICIOS SOLUCIONADOS DEL PROFESOR!
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-19ed79fcb092> in <module>
# ----> 1 x = np.linespace(0, 3*np.pi, 1000)
#       2 x
#
# AttributeError: module 'numpy' has no attribute 'linespace'

# %% [markdown]
# - Crea un gráfico de y en función de x.

# %%
plt.scatter(x, y)

# %% [markdown]
# - Realiza el mismo gráfico anterior pero con una línea discontínua y verde

# %%
plt.scatter(x,y,
         color='g',
         linestyle='dashed',
         marker='H')

# %% [markdown]
# - Añade el título "Función f(x)", y nombra a los ejex "x" e "y"

# %% [markdown]
# - Añade una leyenda que diga "f(x)"

# %% [markdown]
# - Crea otro array z:
#     - z: Resultado de aplicar la función $g(x) = \frac{1}{2}\sin(10 x) + \cos^2(x)$

# %% [markdown]
# - Crea un gráfico de dos columnas.
#     - Realiza un plot sencillo de $f(x)$ y de $g(x)$ en cada uno de ellos

# %% [markdown]
# - Dibuja el mismo gráfico anterior pero con un estilo y color de línea diferente en cada uno.

# %% [markdown]
# - Aumenta el gráfico anterior de tamaño.

# %% [markdown]
# - Añade títulos a los ejes de cada figura, "x", "f(x)" y "g(x)"

# %% [markdown]
# - Guardalo en un fichero .png, .jpeg y .pdf.

# %% [markdown]
# - Ahora superpon en la misma figura ambas funciones con una legenda para cada una ('f(x)' y 'g(x)'), un título que diga "f(x) y g(x)", y nombra a los ejes "x" e "y".

# %% [markdown]
# ---

# %% [markdown]
# ## Distributions

# %% [markdown]
# - Crea dos arrays
#     - normal: Un array de 1000 números aleatorios usando una distribución normal
#     - chi: Un array de 1000 números aleatorios usando una distribución $\chi^2$ con 5 grados de libertad.

# %%
array1 = np.random.normal(size= 1000)
array2 = np.random.chisquare(5, 1000)

# %% [markdown]
# - Crea un scatter plot con los array anteriores.

# %%
plt.scatter(array1, array2)

# %% [markdown]
# - Crea un subplot de dos filas, y pinta en cada una de ellas un histograma para cada una de las distribuciones. Añade título y etiqueta los ejes como consideres.

# %%
fig, (ax1, ax2) = plt.subplots(2,1)
ax1.hist(x, bins=20, color='k', alpha=0.3)
ax2.hist(y, bins=20, color='g', alpha=0.6)
ax1.set_title('My first matplotlib hist')
ax2.set_title('My second matplotlib hist')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-904f30d0a93b> in <module>
# ----> 1 fig, (ax1, ax2) = plt.subplots(1)
#       2 ax1.hist(x, bins=20, color='k', alpha=0.3)
#       3 ax2.hist(y, bins=20, color='g', alpha=0.6)
#       4 ax1.set_title('My first matplotlib hist')
#       5 ax2.set_title('My second matplotlib hist')
#
# TypeError: cannot unpack non-iterable AxesSubplot object

# %% [markdown]
# - Ahora superpon ambas distribuciones en un único plot

# %%
fig, ax = plt.subplots(1)
ax.hist(x, bins=20, color='k', alpha=0.3)
ax.hist(y, bins=20, color='g', alpha=0.6)
# Out:
# (array([23., 22., 24., 29., 25., 29., 18., 24., 20., 25., 35., 22., 21.,
#         29., 23., 26., 26., 28., 25., 26.]),
#  array([ 1. ,  5.9, 10.8, 15.7, 20.6, 25.5, 30.4, 35.3, 40.2, 45.1, 50. ,
#         54.9, 59.8, 64.7, 69.6, 74.5, 79.4, 84.3, 89.2, 94.1, 99. ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ---

# %% [markdown]
# ## Pandas

# %% [markdown]
# - A partir del siguiente dataframe

# %%
s = pd.DataFrame(np.random.randn(100, 4).cumsum(axis=0)+100,
              index=np.arange(0, 100),
             columns=['S1', 'S2', 'S3', 'S4'])
s
# Out:
#             S1          S2         S3         S4
# 0    98.954631   99.584782  99.144269  98.748481
# 1    99.195167  100.072859  98.418485  98.556488
# 2   100.561195  100.606115  98.555362  96.599216
# 3   102.458442   99.451074  99.671098  97.152802
# 4   102.263369   99.269041  99.560549  96.507364
# ..         ...         ...        ...        ...
# 95  107.921667  104.511649  93.674299  98.507761
# 96  107.196926  102.961437  92.532535  98.841565
# 97  107.304596  101.095182  93.758957  98.876593
# 98  108.719958  100.189467  93.930333  98.027090
# 99  106.330580   99.997428  94.699600  97.906901
#
# [100 rows x 4 columns]

# %% [markdown]
# - Pinta todas las series en un úncio plot.

# %%
s.plot()

# %% [markdown]
# - Ahora pintalas en plots separados

# %%
s.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11ea518d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11ebf0f28>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11ecf9390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11ed287f0>],
#       dtype=object)

# %% [markdown]
# - Ahora pinta en un mismo gráfico una de las series anteriores y añade el volumen dado por la serie siguiente

# %%
s['vol'] = pd.Series(np.random.rand(100), index = np.arange(100))*100

# %% [markdown]
# - Mejor separalos en dos plots

# %% [markdown]
# - Hacer plots es como pintar un cuadro, lleva tiempo.
# - [Stock chart plots](https://pythonprogramming.net/advanced-matplotlib-graphing-charting-tutorial/).
