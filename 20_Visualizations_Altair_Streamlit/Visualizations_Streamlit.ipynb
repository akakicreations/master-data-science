# %%
# (Para local + Colab)
# Instalar Streamlite
# !pip install streamlit -q

# %%
# (Para Colab)
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -qq ngrok-stable-linux-amd64.zip
# Out:
# --2020-09-12 09:37:22--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 3.229.211.71, 35.153.56.97, 54.145.36.98, ...
# Connecting to bin.equinox.io (bin.equinox.io)|3.229.211.71|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip.1’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  76.0MB/s    in 0.2s
#
# 2020-09-12 09:37:22 (76.0 MB/s) - ‘ngrok-stable-linux-amd64.zip.1’ saved [13773305/13773305]
#
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename: y

# %%
# (Para Colab)
# Nos da la URL donde se verá el streamlit
get_ipython().system_raw('./ngrok http 8501 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
"import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://2b1755138131.ngrok.io

# %%
# (Para local + Colab)
# %%file hello.py
# Esto estáá dentro del archivo hello.py
import streamlit as st 
import pandas as pd
import altair as alt 
import matplotlib.pyplot as plt 

st.title("Hello world") 

# Mostrar tablas de datos 
brain = pd.read_csv("https://raw.githubusercontent.com/rezpe/datos_viz/master/brain.csv") 
st.table(brain.head()) 

# Mostrar texto 
st.markdown(""" 
## Texto de ejemplo 

Lorem ipsum ... 

""") 

# Mostrar grafico 

# Matplotlib 

plt.scatter(brain["Body Weight"],brain["Brain Weight"]) 
st.pyplot() 

# Altair 
hist_brain = alt.Chart(brain).mark_bar().encode( 
x=alt.X('Brain Weight',bin=alt.Bin(maxbins=100)), 
y="count()" 
).properties( 
width=300, 
height=150, 
title="Relación peso del cerebro y del cuerpo" 
).interactive() 

hist_body = alt.Chart(brain).mark_bar().encode( 
x=alt.X('Body Weight',bin=alt.Bin(maxbins=100)), 
y="count()" 
).properties( 
width=300, 
height=150, 
title="Relación peso del cerebro y del cuerpo" 
).interactive() 

scatter_brain_body = alt.Chart(brain).mark_circle().encode( 
x='Body Weight', 
y='Brain Weight' 
).properties( 
width=700, 
height=300, 
title="Relación peso del cerebro y del cuerpo" 
).interactive() 

comp_brain = (hist_brain|hist_body)&scatter_brain_body 
st.write(comp_brain)
# Out:
# Overwriting hello.py

# %%
# (Para local + Colab)
# Así hacemos que se pueda acceder a la web
# Se queda ejecutando continuamente
# !streamlit run hello.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://104.196.52.61:8501
#
#   Stopping...

# %%
# Ejercicio con Google trends
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## Prueba con otros datos

# %%
# (Para Colab)
# Nos da la URL donde se verá el streamlit
get_ipython().system_raw('./ngrok http 8501 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
"import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://5c9ed7f90076.ngrok.io

# %%
# (Para local + Colab)
# %%file hello.py
# Esto estáá dentro del archivo hello.py
import streamlit as st 
import pandas as pd
import altair as alt 

st.title("Gogole trends") 

# Mostrar texto 
st.markdown("Hemos analizado las búsquedas de 4 tecnologías") 

# Mostrar grafico 
trends = pd.read_csv("https://raw.githubusercontent.com/rezpe/datos_viz/master/google_trends.csv")

trends_line = alt.Chart(trends).mark_line().encode(
    x= 'date:T',
    y="value",
    color='search_term'
)

trends_bar = alt.Chart(trends).mark_bar().encode( 
x="search_term", 
y="value", 
color="search_term" 
).properties(  
title="Titleeeee" 
).interactive() 

comp_trends = trends_bar|trends_line
st.write(comp_trends)

# Mostrar texto 
st.markdown("Puedo hacer zoom para ver al detalle") 

# Mostrar grafico 2
select_date = alt.selection(type='interval', encodings=['x'])

trends_line = alt.Chart(trends).mark_line().encode(
    x= 'yearmonth(date):T',
    y="mean(value)",
    color='search_term'
).properties( 
width=700,
height=100,
title="XXXXXX",  
selection=select_date 
)

mini_trends_line = alt.Chart(trends).mark_line().encode(
    x= 'yearmonth(date):T',
    y="mean(value)",
    color='search_term'
).properties( 
width=700, 
height=300,
title="XXXXXX",  
selection=select_date 
).transform_filter(
    select_date
)

comp_trends2 = trends_line&mini_trends_line
st.write(comp_trends2)
# Out:
# Overwriting hello.py

# %%
# (Para local + Colab)
# Así hacemos que se pueda acceder a la web
# Se queda ejecutando continuamente
# !streamlit run hello.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://104.196.52.61:8501
#
#   Stopping...

# %% [markdown]
# ## Prueba con otros datos

# %%
# Inicio
get_ipython().system_raw('./ngrok http 8501 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
"import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# http://e29d36024e6e.ngrok.io

# %%
# Código
# %%file hello.py
import streamlit as st 
import pandas as pd
import altair as alt 

st.title("GDP Life expectancy") 

# Mostrar texto 
st.markdown("No gathered xxxx xxxxx xxxx") 

# Mostrar grafico 
lifecountries = pd.read_csv("https://raw.githubusercontent.com/rezpe/datos_viz/master/lifecountries.csv")

scatter_expectancy = alt.Chart(lifecountries).mark_circle().encode( 
x='Life Expectancy', 
y='Country GDP', 
color='Continent', 
size='size',
tooltip='Continent'
).properties( 
width=700, 
height=300, 
title="Scatter plot" 
).interactive() 

st.write(scatter_expectancy)
# Out:
# Overwriting hello.py

# %%
# Ejecutar
# !streamlit run hello.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://104.196.52.61:8501
#
#   Stopping...

# %% [markdown]
# # Interactividad en streamlite

# %%
# Inicio
get_ipython().system_raw('./ngrok http 8501 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
"import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://504c4b05137f.ngrok.io

# %%
# Código
# %%file hello.py
import streamlit as st 
import pandas as pd
import altair as alt 

st.title("GDP Life expectancy") 

texto = st.text_input('Insert value')

st.markdown(f"El texto que has escrito es: " + texto)
# Out:
# Overwriting hello.py

# %%
# Ejecutar
# !streamlit run hello.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://104.196.52.61:8501
#
#   Stopping...
#   Stopping...

# %% [markdown]
# ## Otro ejemplo

# %%
# Inicio
get_ipython().system_raw('./ngrok http 8501 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
"import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# http://b4c16dfb50f8.ngrok.io

# %%
# %%file hello.py

import streamlit as st
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt

st.title("Locales de Madrid")

st.markdown("Hemos obtenido la lista de locales de la comunidad de Madrid. Teclee el tipo de local que quiera buscar:")

# CAmpo de input
texto = st.text_input("Insertar tipo","BAR")

# Esto es para que refresque más rápido
@st.cache
def get_locales():
  return pd.read_csv("https://github.com/rezpe/datos_viz/blob/master/locales_madrid.csv?raw=true")

locales = get_locales() 

# Que coja todos los datos
alt.data_transformers.disable_max_rows()

# Filtrar locales que contenga en la columna rótulo...
locales_filt = locales[locales["rotulo"].str.contains(texto)]

# Texto previo
st.markdown(f"La comunidad de Madrid contiene: {len(locales_filt)} {texto}(s) ")

#Gráfico
points = alt.Chart(locales_filt).mark_point().encode(
    latitude="lat",
    longitude="lon",
    color="desc_distrito_local" )

# Descargar fondo de Madrid: remote geojson data object
url_geojson = 'https://raw.githubusercontent.com/codeforamerica/click_that_hood/master/public/data/madrid.geojson' 
data_geojson_remote = alt.Data(url=url_geojson, format=alt.DataFormat(property='features',type='json')) 

# Fondo de Madrid
background = alt.Chart(data_geojson_remote).mark_geoshape( 
).encode( 
).properties( 
) 

# Mostrar
st.write(background+points)
# Out:
# Overwriting hello.py

# %%
# Ejecutar
# !streamlit run hello.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://104.196.52.61:8501
#
# /content/hello.py:17: DtypeWarning: Columns (31,32,37,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   locales = get_locales()
#   Stopping...

# %% [markdown]
# # Ejemplo de interactividades

# %%
# Inicio
get_ipython().system_raw('./ngrok http 8501 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
"import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://894f98831f19.ngrok.io

# %%
# %%file hello.py 

import streamlit as st 
import pandas as pd 
import altair as alt 
import matplotlib.pyplot as plt 
import datetime 

st.button('Say hello') 

agree = st.checkbox('I agree') 

genre = st.radio( 
"What's your favorite movie genre", 
('Comedy', 'Drama', 'Documentary')) 

option = st.selectbox( 
'How would you like to be contacted?', 
('Email', 'Home phone', 'Mobile phone')) 


options = st.multiselect( 
'What are your favorite colors', 
['Green', 'Yellow', 'Red', 'Blue'], 
['Yellow', 'Red']) 

age = st.slider('How old are you?', 0, 130, 25) 

color = st.select_slider( 
'Select a color of the rainbow', 
options=['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet']) 

d = st.date_input( 
"When's your birthday", 
datetime.date(2019, 7, 6)) 


t = st.time_input('Set an alarm for', datetime.time(8, 45)) 

uploaded_file = st.file_uploader("Choose a CSV file", type="csv")
# Out:
# Overwriting hello.py

# %%
# Ejecutar
# !streamlit run hello.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://104.196.52.61:8501
#
#   Stopping...
#   Stopping...

# %% [markdown]
# # Machine Learning example

# %%
# Inicio
get_ipython().system_raw('./ngrok http 8501 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
"import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://7601d11415da.ngrok.io

# %%
# %%file hello.py 

import streamlit as st 
import pandas as pd 
import altair as alt 
import matplotlib.pyplot as plt 
import datetime 
# Load the library with the iris dataset 
from sklearn.datasets import load_iris 
# Load scikit's random forest classifier library 
from sklearn.ensemble import RandomForestClassifier 

st.title("Iris Classifier") 

@st.cache
def get_model():

  # Create an object called iris with the iris data 
  iris = load_iris() 

  # Create a random forest Classifier. By convention, clf means 'Classifier' 
  clf = RandomForestClassifier(n_jobs=-1, random_state=0) 

  # Train the Classifier to take the training features and learn how they relate 
  # to the training y (the species) 
  clf.fit(iris.data, iris.target)

  return clf
clf = get_model()

st.markdown("Change the value of sliders to get predictions") 

feature1 = st.slider('Feature 1', 0, 10) 
feature2 = st.slider('Feature 2', 0, 10) 
feature3 = st.slider('Feature 3', 0, 10) 
feature4 = st.slider('Feature 4', 0, 10) 

prediction = clf.predict([[feature1,feature2,feature3,feature4]]) 

st.write("The prediction is:"+str(prediction))
# Out:
# Overwriting hello.py

# %%
# Ejecutar
# !streamlit run hello.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://104.196.52.61:8501
